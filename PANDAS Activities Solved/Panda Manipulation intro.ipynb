# %%
#!/usr/bin/env python
# coding: utf-8
​
# In[1]:
​
​
import pandas as pd
​
​
# In[7]:
​
​
filepath = "../Solved/Resources/dataSet.csv"
​
​
# In[8]:
​
​
with open(filepath, 'r') as f: 
    lines = f.read()
    for line in lines: 
        print(line)
​
​
# In[11]:
​
​
df = pd.read_csv(filepath)
​
​
# In[14]:
​
​
df.head(10)
​
​
# In[16]:
​
​
df.tail(10)
​
​
# In[17]:
​
​
df.describe()
​
​
# In[19]:
​
​
df.dtypes
​
​
# In[22]:
​
​
df["Amount"].head()
​
​
# In[24]:
​
​
df[["Amount", "Gender"]].head()
​
​
# In[25]:
​
​
df["Amount"].mean()
​
​
# In[26]:
​
​
df["Amount"].sum()
​
​
# In[27]:
​
​
df["Car"].unique()
​
​
# In[29]:
​
​
df["Car"].value_counts()
​
​
# In[32]:
​
​
df["Amount with Inflation"] = df["Amount"] + 100000
​
​
# In[33]:
​
​
df.head()
​
​
# In[34]:
​
​
df["Inflation Percetnage"] = df["Amount"] / df["Amount with Inflation"] * 100
​
​
# In[35]:
​
​
df.head()
​
​
# In[ ]:
​
