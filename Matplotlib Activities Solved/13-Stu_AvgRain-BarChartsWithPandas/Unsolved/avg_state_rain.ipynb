# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
csvpath = "../Resources/avg_rain_state.csv"
df = pd.read_csv(csvpath)
df.head(20)
# Out:
#             State  Inches  Millimetres
# 0          Alaska    43.2         1098
# 1         Alabama    58.9         1495
# 2        Arkansas    55.9         1421
# 3         Arizona    12.6          321
# 4      California    22.2          564
# 5        Colorado    18.9          481
# 6     Connecticut    50.3         1278
# 7        Delaware    49.0         1245
# 8         Florida    55.1         1400
# 9         Georgia    52.7         1338
# 10         Hawaii    58.2         1478
# 11           Iowa    38.7          983
# 12          Idaho    26.8          681
# 13       Illinois    43.1         1096
# 14        Indiana    45.9         1165
# 15         Kansas    31.5          800
# 16       Kentucky    53.8         1367
# 17      Louisiana    61.1         1552
# 18  Massachusetts    49.8         1266
# 19       Maryland    48.5         1231

# %%
df.columns
# Out:
# Index(['State', 'Inches', 'Millimetres'], dtype='object')

# %%
states = df['State']
inches = df['Inches']
x_axis = np.arange(len(states))

# %%
tick_locations = [value for value in x_axis]

# %%
plt.figure(figsize = (30,5))
plt.bar(x_axis, inches, color='r', align='center', alpha = 0.5)
plt.xticks(tick_locations, states, rotation = "vertical")
plt.title("Average Rain per State")
plt.ylabel("Average Amount of Rainfall in Inches")
plt.savefig("myGraph.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="3000">
