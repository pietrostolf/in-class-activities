# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV
union_settlements_df = pd.read_csv("Resources/union_settlements_1995.csv")
union_settlements_df.head()
# Out:
#    SCHEDULE NUMBER  NEGOTIATION NUMBER  BLANK1  \
# 0            17031                  51     NaN
# 1            17031                  52     NaN
# 2            17031                  53     NaN
# 3            17031                  54     NaN
# 4            17031                  55     NaN
#
#                   COMPANY IDENTIFYING INFORMATION   SIC Code  BLANK2  \
# 0  ELEVATOR MANUFACTORS ASSN    LU 1        4799-3       NaN     NaN
# 1  ELEVATOR MANUFACTURING ASSN    LU 1      (4799)       NaN     NaN
# 2                      ELEVATOR MANUFACTURERS ASSN      50.0     NaN
# 3                         ELEVATOR MFRS ASSN  LU 1      50.0     NaN
# 4                   ELEVATOR MFRS ASSN OF NYC  LU1      50.0     NaN
#
#                                SIC Code.1  SIC Code.2  BLANK3  \
# 0  Construction Special Trade Contractors          96     NaN
# 1  Construction Special Trade Contractors          96     NaN
# 2  Construction Special Trade Contractors          96     NaN
# ...

# %%
# Get total settlements by union
groupby_union = union_settlements_df.groupby(["UNION"])
per_union_df = groupby_union.count()
per_union_df2 = per_union_df[["NEGOTIATION NUMBER"]]
per_union_df2
# Out:
#                                                     NEGOTIATION NUMBER
# UNION
# ACTORS EQUITY ASSOCIATION                                            8
# AIR LINE PILOTS                                                     49
# AUTO WORKERS                                                       322
# BAKERY, CONFECTIONERY WORKERS INTERNATIONAL UNI...                  19
# CLOTHING AND TEXTILE WORKERS                                       120
# ELEVATOR CONSTRUCTORS                                                8

# %%
# Configure plot, figsize, title, and axis labels
set_plot = per_union_df2.plot(kind='bar', figsize=(8, 6))
plt.title("Major Collective Barganing Settlements (1995)")
set_plot.set_xticklabels(per_union_df2.index,rotation = 45,ha="right")
set_plot.set_ylabel("number of settlements")
plt.tight_layout()
plt.show()

# Configure x-tick rotation


# Show plot
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Resize plot to display labels
